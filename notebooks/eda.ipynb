# %%
# Data Visualizations and Summary Statistics

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/X_train_data.csv")

# %%
df
# Out:
#       Episodes  Popularity  Members  Favorites  Watching  Completed  On-Hold  \
# 0          2.0      5358.0   8040.0       11.0     217.0     5118.0    115.0
# 1          1.0      4666.0  11366.0       16.0     343.0     6793.0    189.0
# 2          1.0      9773.0   1379.0        1.0      45.0      705.0     17.0
# 3          1.0      9408.0   1594.0        0.0      50.0      843.0     25.0
# 4         12.0     10923.0    812.0        0.0      33.0      459.0     31.0
# ...        ...         ...      ...        ...       ...        ...      ...
# 9826       1.0      9261.0   1712.0        0.0      78.0     1019.0     15.0
# 9827       1.0      7405.0   3577.0       36.0      37.0     3124.0     12.0
# 9828       1.0     10825.0    846.0        0.0      31.0      391.0     15.0
# 9829      39.0      1677.0  79685.0     1186.0    5702.0    35803.0   5003.0
# 9830      51.0      8818.0   2020.0        6.0     231.0      319.0    157.0
#
#       Dropped  Plan to Watch  Type_Movie  ...  Sports  Super Power  \
# 0       115.0         2475.0           0  ...       1            0
# 1       169.0         3872.0           0  ...       0            1
# 2        47.0          565.0           0  ...       0            0
# 3        68.0          608.0           1  ...       0            0
# 4        84.0          205.0           0  ...       0            0
# ...       ...            ...         ...  ...     ...          ...
# 9826     63.0          537.0           0  ...       0            0
# 9827     35.0          369.0           0  ...       0            0
# 9828     40.0          369.0           0  ...       0            0
# 9829   3975.0        29202.0           0  ...       0            0
# 9830    325.0          988.0           0  ...       0            0
#
#       Supernatural  Thriller  Unknown  Vampire  Yaoi  Yuri  Year  Seconds
# 0                0         0        0        0     0     0  2016   1440.0
# 1                0         0        0        0     0     0  2014     60.0
# 2                1         0        0        0     0     0  1987   1860.0
# 3                0         0        0        0     0     0  1999   5640.0
# 4                0         0        0        0     0     0  2007    120.0
# ...            ...       ...      ...      ...   ...   ...   ...      ...
# 9826             0         0        0        0     0     0  2019   1380.0
# 9827             0         0        0        0     0     0  2008    180.0
# 9828             0         0        0        0     0     0  1987   3480.0
# 9829             0         0        0        0     0     0  2006   1500.0
# 9830             1         0        0        0     0     0  2013   1440.0
#
# [9831 rows x 84 columns]

# %%
df.columns
# Out:
# Index(['Episodes', 'Popularity', 'Members', 'Favorites', 'Watching',
#        'Completed', 'On-Hold', 'Dropped', 'Plan to Watch', 'Type_Movie',
#        'Type_Music', 'Type_ONA', 'Type_OVA', 'Type_Special', 'Type_TV',
#        'Source_4-koma manga', 'Source_Book', 'Source_Card game',
#        'Source_Digital manga', 'Source_Game', 'Source_Light novel',
#        'Source_Manga', 'Source_Music', 'Source_Novel', 'Source_Original',
#        'Source_Other', 'Source_Picture book', 'Source_Radio', 'Source_Unknown',
#        'Source_Visual novel', 'Source_Web manga', 'Rating_G - All Ages',
#        'Rating_PG - Children', 'Rating_PG-13 - Teens 13 or older',
#        'Rating_R - 17+ (violence & profanity)', 'Rating_R+ - Mild Nudity',
#        'Rating_Rx - Hentai', 'Rating_Unknown', 'Action', 'Adventure', 'Cars',
#        'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game',
#        'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic',
#        'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody',
#        'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi',
#        'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai',
#        'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural',
#        'Thriller', 'Unknown', 'Vampire', 'Yaoi', 'Yuri', 'Year', 'Seconds'],
#       dtype='object')

# %%
#grab all the genre column

df_genre = df[['Action', 'Adventure', 'Cars',
       'Comedy', 'Dementia', 'Demons', 'Drama', 'Ecchi', 'Fantasy', 'Game',
       'Harem', 'Hentai', 'Historical', 'Horror', 'Josei', 'Kids', 'Magic',
       'Martial Arts', 'Mecha', 'Military', 'Music', 'Mystery', 'Parody',
       'Police', 'Psychological', 'Romance', 'Samurai', 'School', 'Sci-Fi',
       'Seinen', 'Shoujo', 'Shoujo Ai', 'Shounen', 'Shounen Ai',
       'Slice of Life', 'Space', 'Sports', 'Super Power', 'Supernatural',
       'Thriller', 'Unknown', 'Vampire', 'Yaoi', 'Yuri']]

# %%
df_genre_counts = df_genre.sum().sort_values(ascending=False).reset_index()

labels = df_genre_counts.head(10)

# %% [markdown]
# The top ten genres represented in this dataset

# %%
plt.bar(x=labels['index'], height = labels[0])
plt.xticks(rotation=90)
plt.xlabel("Anime Genre")
plt.ylabel("Count of Occurences")
plt.title("Amount of occurrences for the top 10 genres")
plt.show()

# %%
df_genre_counts = df_genre.sum().sort_values().reset_index()
min_labels = df_genre_counts.head(10)

# %%
plt.bar(x=min_labels['index'], height = min_labels[0])
plt.xticks(rotation=90)
plt.xlabel("Anime Genre")
plt.ylabel("Count of Occurences")
plt.title("Amount of occurrences for the lowest 10 genres")
plt.show()

# %%
year = df.groupby("Year", as_index=False).count()
counts_by_year = year.iloc[:, :2]
counts_by_year
# Out:
#     Year  Episodes
# 0   1917         6
# 1   1918         1
# 2   1924         1
# 3   1925         4
# 4   1926         3
# ..   ...       ...
# 90  2017       509
# 91  2018       504
# 92  2019       410
# 93  2020       305
# 94  2021        49
#
# [95 rows x 2 columns]

# %%
plt.plot(counts_by_year["Year"], counts_by_year["Episodes"])
plt.xlabel("Year")
plt.ylabel("Count")
plt.title("Counts of Anime releases by Year")
plt.show()

# %%
for type in ['Type_Movie', 'Type_Music', 'Type_ONA', 'Type_OVA', 'Type_Special', 'Type_TV']:
    df_type = df[df[type]==1]
    name = type.split("_")[1]
    plt.boxplot(df_type["Seconds"], vert=False)
    plt.xlabel("Seconds")
    plt.title(f"Box and Whisker Plot for the duration (in seconds) of: {name}")
    plt.show()

# %%
des_lis = ["Popularity", 'Members', 'Favorites', 'Watching', 'Completed', 'On-Hold', 'Dropped', 'Plan to Watch']
for item in des_lis:
    print(f"Here are some descriptive stats for the {item} column:")
    print(df[item].describe())
# Out:
# Here are some descriptive stats for the Popularity column:
# count     9831.000000
# mean      6428.194690
# std       3845.790253
# min          1.000000
# 25%       3118.500000
# 50%       6317.000000
# 75%       9578.500000
# max      15374.000000
# Name: Popularity, dtype: float64
# Here are some descriptive stats for the Members column:
# count    9.831000e+03
# mean     4.870160e+04
# std      1.465632e+05
# min      1.720000e+02
# 25%      1.489000e+03
# 50%      5.342000e+03
# 75%      2.756150e+04
# max      2.589552e+06
# Name: Members, dtype: float64
# Here are some descriptive stats for the Favorites column:
# count      9831.000000
# mean        653.582647
# std        4847.142010
# min           0.000000
# 25%           2.000000
# 50%          10.000000
# 75%          73.000000
# max      183914.000000
# Name: Favorites, dtype: float64
# Here are some descriptive stats for the Watching column:
# count      9831.000000
# mean       3119.283389
# std       15335.806923
# min           0.000000
# 25%          54.000000
# 50%         217.000000
# 75%        1015.500000
# max      566239.000000
# Name: Watching, dtype: float64
# Here are some descriptive stats for the Completed column:
# count    9.831000e+03
# mean     3.130807e+04
# std      1.066163e+05
# min      0.000000e+00
# 25%      6.610000e+02
# 50%      2.745000e+03
# 75%      1.530000e+04
# max      2.146116e+06
# Name: Completed, dtype: float64
# Here are some descriptive stats for the On-Hold column:
# count      9831.000000
# mean       1338.742244
# std        4816.230254
# min           0.000000
# 25%          33.000000
# 50%         135.000000
# 75%         576.000000
# max      130961.000000
# Name: On-Hold, dtype: float64
# Here are some descriptive stats for the Dropped column:
# count      9831.000000
# mean       1639.116265
# std        5483.523501
# min           0.000000
# 25%          62.000000
# 50%         145.000000
# 75%         570.000000
# max      174710.000000
# Name: Dropped, dtype: float64
# Here are some descriptive stats for the Plan to Watch column:
# count      9831.000000
# mean      11296.385312
# std       27703.038677
# min          12.000000
# 25%         516.000000
# 50%        1738.000000
# 75%        7636.000000
# max      425531.000000
# Name: Plan to Watch, dtype: float64
